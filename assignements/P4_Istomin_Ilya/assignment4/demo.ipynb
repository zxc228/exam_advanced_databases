# %% [markdown]
# # Imports

# %%
from logistics.graph import GraphManager
from logistics.routes import RouteManager
from logistics.fleet import FleetManager
from logistics.package import PackageManager
from config import Config
import logistics.utils as utils
from datetime import datetime, timedelta
import pprint

# %% [markdown]
# # Init of Graph

# %% [markdown]
# You can change your nodes and cities in file /logistics/utils.py

# %%
graph_manager = GraphManager(
        uri='bolt://localhost:7687',
        user=Config.user,
        password=Config.password,
        transport_params=utils.transport_params,
        nodes=utils.nodes,
        edges=utils.edges
    )
graph_manager.reset_graph()
graph_manager.setup_graph()
# Out:
# All nodes and relationships have been deleted.
# All indexes have been deleted.
# All constraints have been deleted.
# Nodes created.
# Relationships created.

# %% [markdown]
# # Init of all Managers

# %%
route_manager = RouteManager(graph_manager)
fleet_manager = FleetManager()
package_manager = PackageManager(fleet_manager, time_threshold=10)

# %% [markdown]
# ## Setting start time

# %%
start_time = datetime(2024, 1, 1, 8, 0, 0)

# %% [markdown]
# ## Testing routes

# %%
print("Example Routes (Same_day):")
routes_1 = route_manager.find_delivery_options("Bilbao", "Palma", start_time)
routes_2 = route_manager.find_delivery_options("Barcelona", "Zaragoza", start_time)
routes_3 = route_manager.find_delivery_options("Valencia", "Alicante", start_time)
routes_4 = route_manager.find_delivery_options("Madrid", "Seville", start_time)

print("Route Bilbao -> Palma:")
print('Available delivery types:', routes_1.keys())

print('Route Barcelona -> Zaragoza:')
print('Available delivery types:', routes_2.keys())

print('Route Valencia -> Alicante:')
print('Available delivery types:', routes_3.keys())

print('Route Madrid -> Seville:')
print('Available delivery types:', routes_4.keys())

route_manager.route_output(routes_1["Same_day"])
route_manager.route_output(routes_2["Same_day"])
route_manager.route_output(routes_3["Same_day"])
route_manager.route_output(routes_4["Same_day"])
# Out:
# Example Routes (Same_day):
# Route Bilbao -> Palma:
# Available delivery types: dict_keys(['Same_day'])
# Route Barcelona -> Zaragoza:
# Available delivery types: dict_keys(['Same_day'])
# Route Valencia -> Alicante:
# Available delivery types: dict_keys(['Same_day'])
# Route Madrid -> Seville:
# Available delivery types: dict_keys(['Same_day'])
# Route:
# Bilbao -> Zaragoza -> Barcelona -> Palma
#
# Total route cost: 13.55 units
# Total route time: 425.00 minutes
#
# Total route distance: 850 km
# Average delivery speed: 120.00 km/h
# Transport changes: 1
# Route details:
# From Bilbao to Zaragoza:
#   - Transport: railway
#   - Distance: 300 km
#   - Unload time: 0 minutes
#   - Load time: 10 minutes
#   - Travel time: 150.00 minutes
#   - Total segment time: 160.00 minutes
#   - Segment cost: 2.40 units
#
# From Zaragoza to Barcelona:
#   - Transport: railway
#   - Distance: 300 km
#   - Unload time: 0 minutes
#   - Load time: 0 minutes
#   - Travel time: 150.00 minutes
#   - Total segment time: 150.00 minutes
#   - Segment cost: 2.40 units
#
# From Barcelona to Palma:
#   - Transport: aerial
#   - Distance: 250 km
#   - Unload time: 50 minutes
#   - Load time: 40 minutes
#   - Travel time: 25.00 minutes
#   - Total segment time: 115.00 minutes
#   - Segment cost: 8.75 units
#
# Route:
# Barcelona -> Zaragoza
#
# Total route cost: 2.40 units
# Total route time: 170.00 minutes
#
# Total route distance: 300 km
# Average delivery speed: 105.88 km/h
# Transport changes: 0
# Route details:
# From Barcelona to Zaragoza:
#   - Transport: railway
#   - Distance: 300 km
#   - Unload time: 10 minutes
#   - Load time: 10 minutes
#   - Travel time: 150.00 minutes
#   - Total segment time: 170.00 minutes
#   - Segment cost: 2.40 units
#
# Route:
# Valencia -> Alicante
#
# Total route cost: 1.80 units
# Total route time: 118.00 minutes
#
# Total route distance: 180 km
# Average delivery speed: 91.53 km/h
# Transport changes: 0
# Route details:
# From Valencia to Alicante:
#   - Transport: road
#   - Distance: 180 km
#   - Unload time: 5 minutes
#   - Load time: 5 minutes
#   - Travel time: 108.00 minutes
#   - Total segment time: 118.00 minutes
#   - Segment cost: 1.80 units
#
# Route:
# Madrid -> Seville
#
# Total route cost: 4.24 units
# Total route time: 285.00 minutes
#
# Total route distance: 530 km
# Average delivery speed: 111.58 km/h
# Transport changes: 0
# Route details:
# From Madrid to Seville:
#   - Transport: railway
#   - Distance: 530 km
#   - Unload time: 10 minutes
#   - Load time: 10 minutes
#   - Travel time: 265.00 minutes
#   - Total segment time: 285.00 minutes
#   - Segment cost: 4.24 units

# %% [markdown]
# ## Registering packages

# %%
pkg_id_1 = package_manager.register_package(routes_1, "Same_day", start_time)
pkg_id_2 = package_manager.register_package(routes_2, "Same_day", start_time)
pkg_id_3 = package_manager.register_package(routes_2, "Same_day", start_time + timedelta(minutes=5))
pkg_id_4 = package_manager.register_package(routes_3, "Same_day", start_time)
pkg_id_5 = package_manager.register_package(routes_4, "Same_day", start_time + timedelta(minutes=3))

# %% [markdown]
# ## Working wth PackageManager

# %%
# Apply delays
package_manager.apply_delay(pkg_id_1, 10)

# Assign vehicles for initial segments
package_manager.assign_initial_vehicles()

# Generate the final delivery schedule
schedule = package_manager.create_schedule()

# %% [markdown]
# ## Output of PackageManager

# %%
print("\nFinal Delivery Schedule:")
pprint.pprint(schedule)

# Pretty-formatted schedule output
print("\nFormatted Schedule by Segments:")
for pkg_id, pkg_sched in schedule.items():
    print(f"\nPackage {pkg_id}:")
    print(f"  Delivery Type: {pkg_sched['delivery_type']}")
    print(f"  Final Start Time: {pkg_sched['final_start_time']}")
    print(f"  Delay: {pkg_sched['delay']} minutes")
    print(f"  Route: {' -> '.join(pkg_sched['route'])}")

    for i, seg in enumerate(pkg_sched["detailed_segments"], 1):
        print(f"  Segment {i}:")
        print(f"    From: {seg['from']} to {seg['to']} via {seg['transport']}")
        print(f"    Segment Start Time: {seg['segment_start']}")
        print(f"    Loading: {seg['load_start']} ({seg['load_time']} mins)")
        print(f"    Departure: {seg['depart_time']}, Arrival: {seg['arrival_time']}")
        print(f"    Unloading: {seg['unload_time']} mins, Segment End: {seg['segment_end']}")
        print(f"    Vehicle ID: {seg['vehicle_id']}")
        print(f"    Segment Cost: {seg['total_cost']}, Total Time: {seg['total_time']} mins\n")
# Out:
# Final Delivery Schedule:
# {1: {'delay': 10,
#      'delivery_type': 'Same_day',
#      'detailed_segments': [{'arrival_time': datetime.datetime(2024, 1, 1, 10, 50),
#                             'depart_time': datetime.datetime(2024, 1, 1, 8, 20),
#                             'from': 'Bilbao',
#                             'load_start': datetime.datetime(2024, 1, 1, 8, 10),
#                             'load_time': 10,
#                             'segment_end': datetime.datetime(2024, 1, 1, 10, 50),
#                             'segment_start': datetime.datetime(2024, 1, 1, 8, 10),
#                             'to': 'Zaragoza',
#                             'total_cost': 2.4000000000000004,
#                             'total_time': 160.0,
#                             'transport': 'railway',
#                             'travel_time': 150.0,
#                             'unload_time': 0,
#                             'vehicle_id': 1},
#                            {'arrival_time': datetime.datetime(2024, 1, 1, 13, 20),
#                             'depart_time': datetime.datetime(2024, 1, 1, 10, 50),
#                             'from': 'Zaragoza',
#                             'load_start': datetime.datetime(2024, 1, 1, 10, 50),
#                             'load_time': 0,
#                             'segment_end': datetime.datetime(2024, 1, 1, 13, 20),
#                             'segment_start': datetime.datetime(2024, 1, 1, 10, 50),
#                             'to': 'Barcelona',
#                             'total_cost': 2.4000000000000004,
#                             'total_time': 150.0,
#                             'transport': 'railway',
#                             'travel_time': 150.0,
#                             'unload_time': 0,
#                             'vehicle_id': 5},
#                            {'arrival_time': datetime.datetime(2024, 1, 1, 14, 25),
#                             'depart_time': datetime.datetime(2024, 1, 1, 14, 0),
#                             'from': 'Barcelona',
#                             'load_start': datetime.datetime(2024, 1, 1, 13, 20),
#                             'load_time': 40,
#                             'segment_end': datetime.datetime(2024, 1, 1, 15, 15),
#                             'segment_start': datetime.datetime(2024, 1, 1, 13, 20),
#                             'to': 'Palma',
#                             'total_cost': 8.75,
#                             'total_time': 115.0,
#                             'transport': 'aerial',
#                             'travel_time': 25.0,
#                             'unload_time': 50,
#                             'vehicle_id': 6}],
#      'final_start_time': datetime.datetime(2024, 1, 1, 8, 10),
#      'route': ['Bilbao', 'Zaragoza', 'Barcelona', 'Palma']},
#  2: {'delay': 0,
#      'delivery_type': 'Same_day',
#      'detailed_segments': [{'arrival_time': datetime.datetime(2024, 1, 1, 10, 40),
#                             'depart_time': datetime.datetime(2024, 1, 1, 8, 10),
#                             'from': 'Barcelona',
#                             'load_start': datetime.datetime(2024, 1, 1, 8, 0),
#                             'load_time': 10,
#                             'segment_end': datetime.datetime(2024, 1, 1, 10, 50),
#                             'segment_start': datetime.datetime(2024, 1, 1, 8, 0),
#                             'to': 'Zaragoza',
#                             'total_cost': 2.4000000000000004,
#                             'total_time': 170.0,
#                             'transport': 'railway',
#                             'travel_time': 150.0,
#                             'unload_time': 10,
#                             'vehicle_id': 2}],
#      'final_start_time': datetime.datetime(2024, 1, 1, 8, 0),
#      'route': ['Barcelona', 'Zaragoza']},
#  3: {'delay': 0,
#      'delivery_type': 'Same_day',
#      'detailed_segments': [{'arrival_time': datetime.datetime(2024, 1, 1, 10, 45),
#                             'depart_time': datetime.datetime(2024, 1, 1, 8, 15),
#                             'from': 'Barcelona',
#                             'load_start': datetime.datetime(2024, 1, 1, 8, 5),
#                             'load_time': 10,
#                             'segment_end': datetime.datetime(2024, 1, 1, 10, 55),
#                             'segment_start': datetime.datetime(2024, 1, 1, 8, 5),
#                             'to': 'Zaragoza',
#                             'total_cost': 2.4000000000000004,
#                             'total_time': 170.0,
#                             'transport': 'railway',
#                             'travel_time': 150.0,
#                             'unload_time': 10,
#                             'vehicle_id': 2}],
#      'final_start_time': datetime.datetime(2024, 1, 1, 8, 5),
#      'route': ['Barcelona', 'Zaragoza']},
#  4: {'delay': 0,
#      'delivery_type': 'Same_day',
#      'detailed_segments': [{'arrival_time': datetime.datetime(2024, 1, 1, 9, 53),
#                             'depart_time': datetime.datetime(2024, 1, 1, 8, 5),
#                             'from': 'Valencia',
#                             'load_start': datetime.datetime(2024, 1, 1, 8, 0),
#                             'load_time': 5,
#                             'segment_end': datetime.datetime(2024, 1, 1, 9, 58),
#                             'segment_start': datetime.datetime(2024, 1, 1, 8, 0),
#                             'to': 'Alicante',
#                             'total_cost': 1.8,
#                             'total_time': 118.0,
#                             'transport': 'road',
#                             'travel_time': 108.0,
#                             'unload_time': 5,
#                             'vehicle_id': 3}],
#      'final_start_time': datetime.datetime(2024, 1, 1, 8, 0),
#      'route': ['Valencia', 'Alicante']},
#  5: {'delay': 0,
#      'delivery_type': 'Same_day',
#      'detailed_segments': [{'arrival_time': datetime.datetime(2024, 1, 1, 12, 38),
#                             'depart_time': datetime.datetime(2024, 1, 1, 8, 13),
#                             'from': 'Madrid',
#                             'load_start': datetime.datetime(2024, 1, 1, 8, 3),
#                             'load_time': 10,
#                             'segment_end': datetime.datetime(2024, 1, 1, 12, 48),
#                             'segment_start': datetime.datetime(2024, 1, 1, 8, 3),
#                             'to': 'Seville',
#                             'total_cost': 4.24,
#                             'total_time': 285.0,
#                             'transport': 'railway',
#                             'travel_time': 265.0,
#                             'unload_time': 10,
#                             'vehicle_id': 4}],
#      'final_start_time': datetime.datetime(2024, 1, 1, 8, 3),
#      'route': ['Madrid', 'Seville']}}
#
# Formatted Schedule by Segments:
#
# Package 1:
#   Delivery Type: Same_day
#   Final Start Time: 2024-01-01 08:10:00
#   Delay: 10 minutes
#   Route: Bilbao -> Zaragoza -> Barcelona -> Palma
#   Segment 1:
#     From: Bilbao to Zaragoza via railway
#     Segment Start Time: 2024-01-01 08:10:00
#     Loading: 2024-01-01 08:10:00 (10 mins)
#     Departure: 2024-01-01 08:20:00, Arrival: 2024-01-01 10:50:00
#     Unloading: 0 mins, Segment End: 2024-01-01 10:50:00
#     Vehicle ID: 1
#     Segment Cost: 2.4000000000000004, Total Time: 160.0 mins
#
#   Segment 2:
#     From: Zaragoza to Barcelona via railway
#     Segment Start Time: 2024-01-01 10:50:00
#     Loading: 2024-01-01 10:50:00 (0 mins)
#     Departure: 2024-01-01 10:50:00, Arrival: 2024-01-01 13:20:00
#     Unloading: 0 mins, Segment End: 2024-01-01 13:20:00
#     Vehicle ID: 5
#     Segment Cost: 2.4000000000000004, Total Time: 150.0 mins
#
#   Segment 3:
#     From: Barcelona to Palma via aerial
#     Segment Start Time: 2024-01-01 13:20:00
#     Loading: 2024-01-01 13:20:00 (40 mins)
#     Departure: 2024-01-01 14:00:00, Arrival: 2024-01-01 14:25:00
#     Unloading: 50 mins, Segment End: 2024-01-01 15:15:00
#     Vehicle ID: 6
#     Segment Cost: 8.75, Total Time: 115.0 mins
#
#
# Package 2:
#   Delivery Type: Same_day
#   Final Start Time: 2024-01-01 08:00:00
#   Delay: 0 minutes
#   Route: Barcelona -> Zaragoza
#   Segment 1:
#     From: Barcelona to Zaragoza via railway
#     Segment Start Time: 2024-01-01 08:00:00
#     Loading: 2024-01-01 08:00:00 (10 mins)
#     Departure: 2024-01-01 08:10:00, Arrival: 2024-01-01 10:40:00
#     Unloading: 10 mins, Segment End: 2024-01-01 10:50:00
#     Vehicle ID: 2
#     Segment Cost: 2.4000000000000004, Total Time: 170.0 mins
#
#
# Package 3:
#   Delivery Type: Same_day
#   Final Start Time: 2024-01-01 08:05:00
#   Delay: 0 minutes
#   Route: Barcelona -> Zaragoza
#   Segment 1:
#     From: Barcelona to Zaragoza via railway
#     Segment Start Time: 2024-01-01 08:05:00
#     Loading: 2024-01-01 08:05:00 (10 mins)
#     Departure: 2024-01-01 08:15:00, Arrival: 2024-01-01 10:45:00
#     Unloading: 10 mins, Segment End: 2024-01-01 10:55:00
#     Vehicle ID: 2
#     Segment Cost: 2.4000000000000004, Total Time: 170.0 mins
#
#
# Package 4:
#   Delivery Type: Same_day
#   Final Start Time: 2024-01-01 08:00:00
#   Delay: 0 minutes
#   Route: Valencia -> Alicante
#   Segment 1:
#     From: Valencia to Alicante via road
#     Segment Start Time: 2024-01-01 08:00:00
#     Loading: 2024-01-01 08:00:00 (5 mins)
#     Departure: 2024-01-01 08:05:00, Arrival: 2024-01-01 09:53:00
#     Unloading: 5 mins, Segment End: 2024-01-01 09:58:00
#     Vehicle ID: 3
#     Segment Cost: 1.8, Total Time: 118.0 mins
#
#
# Package 5:
#   Delivery Type: Same_day
#   Final Start Time: 2024-01-01 08:03:00
#   Delay: 0 minutes
#   Route: Madrid -> Seville
#   Segment 1:
#     From: Madrid to Seville via railway
#     Segment Start Time: 2024-01-01 08:03:00
#     Loading: 2024-01-01 08:03:00 (10 mins)
#     Departure: 2024-01-01 08:13:00, Arrival: 2024-01-01 12:38:00
#     Unloading: 10 mins, Segment End: 2024-01-01 12:48:00
#     Vehicle ID: 4
#     Segment Cost: 4.24, Total Time: 285.0 mins
